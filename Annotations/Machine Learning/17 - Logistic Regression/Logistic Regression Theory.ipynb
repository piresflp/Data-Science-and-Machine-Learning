# %% [markdown]
# * A method for <strong>Classification</strong>
#
# * Allow us to solve classification problems, where we are trying to predict discrete categories.
#
# * A logistic regression curve can only go between 0 and 1.
#
# ![image.png](attachment:image.png)
#
# ##### -> We can set a cutoff point at 0.5, anything below it results in class 0, anything above is class 1.
#
#
# #### Accuracy of a Confusion Matrix:
# (TP+TN) / total
#
# #### Misclassification Rate (Error Rate):
# (FP + FN) / total
#
# <strong> (Acurracy + Error Rate = 1 | 100%)
