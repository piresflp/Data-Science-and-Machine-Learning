# %% [markdown]
# * So after the network creates its prediction, how do we evaluate it? And after the evaluation how can we update the network's weights and biases?
#
#
# * We need to take the estimated outputs of the network and then compare them to the real values of the label.
#
#
# * The cost function (often referred to as a loss function) measures how far off you are from the true value based on your prediction. Must be an average so it can output a single value.
#
#
# * We'll use the following variables:
#     * y to represent the true value
#     * a to represent neuron's prediction
#
#
# * In terms of weights and bias:
#     * w*x+b = z
#     * Pass z into activation function
#
#
#
# ![image.png](attachment:image.png)
