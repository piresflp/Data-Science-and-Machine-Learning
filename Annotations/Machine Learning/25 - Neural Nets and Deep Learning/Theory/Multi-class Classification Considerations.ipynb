# %% [markdown]
# * There are 2 main types of multi-class
#     * Non-Exclusive Classes
#         * A data point can have multiple classes/categories assigned to it.
#
#  * Mutually Exclusive Classes
#      * Only one class per data point.
#
#
#
#
# * Organizing Multiple Classes
#     * The easiest way to organize multiple classes is to simply have 1 output node per class.
#     ![image.png](attachment:image.png)
#     * use <strong>one-hot enconding</strong> (binary classification for each class)
#
#
#
# * Non-Exclusive Classes
# ![image-2.png](attachment:image-2.png)
#
#
#
#
#
#
#
# * Sigmoid function for Non-Exclusive Classes
# ![image-3.png](attachment:image-3.png)
# This allows each neuron to output independent of the other classes, allowing for a single data point fed into the function to have multiple classes assigned to it.
